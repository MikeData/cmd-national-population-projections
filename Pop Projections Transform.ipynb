# %%
import pandas as pd

df = pd.read_csv("Experimental-National Population Projections.csv")

df.columns.values
# Out:
# array(['V4_0', 'time', 'time_codelist', 'geography', 'geography_codelist',
#        'sex_codelist', 'sex', 'age_codelist', 'age',
#        'projectiontype_codelist', 'projectiontype',
#        'populationmeasure_codelist', 'populationmeasure'], dtype=object)

# %%
df["populationmeasure"].unique()
# Out:
# array(['Births', 'Cross_border_rates', 'Deaths', 'Fertility_assumptions',
#        'International_migration(In)', 'International_migration(Out)',
#        'International_migration(Net)', 'Mortality_assumptions',
#        'Population', 'Total_migration(In)', 'Total_migration(Out)',
#        'Total_migration(Net)'], dtype=object)

# %%
df["projectiontype"].unique()
# Out:
# array(['Low life expectancy', 'High migration', 'Low migration',
#        'Principal', 'Zero net migration (natural change only)',
#        'High population', 'High fertility', 'Low population',
#        'Low fertility', 'High life expectancy'], dtype=object)

# %%
# Migration

wanted = [
        'International_migration(In)', 'International_migration(Out)',
        'International_migration(Net)', 'Total_migration(In)', 
        'Total_migration(Out)', 'Total_migration(Net)'
            ]

migration = df.copy()
for pt in migration["populationmeasure"].unique():
    
    if pt not in wanted:
        migration = migration[migration["populationmeasure"] != pt]
        
        
migration.to_csv("NPP_Migration.csv", index=False)

migration[:3] # sanity check
# Out:
#          V4_0         time time_codelist       geography geography_codelist  \
# 30824  2604.0  2016 - 2017          Year  United Kingdom          K02000001
# 30825  4544.0  2016 - 2017          Year  United Kingdom          K02000001
# 30826  4069.0  2016 - 2017          Year  United Kingdom          K02000001
#
#        sex_codelist  sex age_codelist age projectiontype_codelist  \
# 30824           1.0  1.0            0   0     low-life-expectancy
# 30825           1.0  1.0            1   1     low-life-expectancy
# 30826           1.0  1.0            2   2     low-life-expectancy
#
#             projectiontype   populationmeasure_codelist  \
# 30824  Low life expectancy  international_migration(in)
# 30825  Low life expectancy  international_migration(in)
# 30826  Low life expectancy  international_migration(in)
#
#                  populationmeasure
# 30824  International_migration(In)
# 30825  International_migration(In)
# 30826  International_migration(In)

# %%
# Deaths

deaths = df.copy()
deaths = deaths[deaths["populationmeasure"] == "Deaths"]
deaths = deaths.drop("populationmeasure", axis=1)
deaths = deaths.drop("populationmeasure_codelist", axis=1)

deaths.to_csv("NPP_Deaths.csv", index=False)

deaths[:3] # sanity check
# Out:
#         V4_0         time time_codelist       geography geography_codelist  \
# 6224  1382.0  2016 - 2017          Year  United Kingdom          K02000001
# 6225   332.0  2016 - 2017          Year  United Kingdom          K02000001
# 6226   108.0  2016 - 2017          Year  United Kingdom          K02000001
#
#       sex_codelist  sex age_codelist    age projectiontype_codelist  \
# 6224           1.0  1.0        birth  Birth     low-life-expectancy
# 6225           1.0  1.0            0      0     low-life-expectancy
# 6226           1.0  1.0            1      1     low-life-expectancy
#
#            projectiontype
# 6224  Low life expectancy
# 6225  Low life expectancy
# 6226  Low life expectancy

# %%
# Mortality Assumptions

mAssumptions = df.copy()
mAssumptions = mAssumptions[mAssumptions["populationmeasure"] == "Mortality_assumptions"]
mAssumptions = mAssumptions.drop("populationmeasure", axis=1)
mAssumptions = mAssumptions.drop("populationmeasure_codelist", axis=1)

mAssumptions.to_csv("NPP_MortalityAssumptions.csv", index=False)

mAssumptions[:3] # sanity check
# Out:
#              V4_0         time time_codelist       geography  \
# 94424  354.172807  2016 - 2017          Year  United Kingdom
# 94425   82.469208  2016 - 2017          Year  United Kingdom
# 94426   26.706628  2016 - 2017          Year  United Kingdom
#
#       geography_codelist  sex_codelist  sex age_codelist    age  \
# 94424          K02000001           1.0  1.0        birth  Birth
# 94425          K02000001           1.0  1.0            0      0
# 94426          K02000001           1.0  1.0            1      1
#
#       projectiontype_codelist       projectiontype
# 94424     low-life-expectancy  Low life expectancy
# 94425     low-life-expectancy  Low life expectancy
# 94426     low-life-expectancy  Low life expectancy

# %%
# Population

population = df.copy()
population = population[population["populationmeasure"] == "Population"]
population = population.drop("populationmeasure", axis=1)
population = population.drop("populationmeasure_codelist", axis=1)

population.to_csv("NPP_PopulationNumbers.csv", index=False)

population[:3] # sanity check
# Out:
#             V4_0  time time_codelist       geography geography_codelist  \
# 119824  401630.0  2016          Year  United Kingdom          K02000001
# 119825  402554.0  2016          Year  United Kingdom          K02000001
# 119826  406751.0  2016          Year  United Kingdom          K02000001
#
#         sex_codelist  sex age_codelist age projectiontype_codelist  \
# 119824           1.0  1.0            0   0     low-life-expectancy
# 119825           1.0  1.0            1   1     low-life-expectancy
# 119826           1.0  1.0            2   2     low-life-expectancy
#
#              projectiontype
# 119824  Low life expectancy
# 119825  Low life expectancy
# 119826  Low life expectancy

# %%
# Births and Fertility Assumptions

wanted = [
        'Fertility_assumptions', 'Births'
            ]

birthsAndFertility = df.copy()
for pt in birthsAndFertility["populationmeasure"].unique():
    
    if pt not in wanted:
        birthsAndFertility = birthsAndFertility[birthsAndFertility["populationmeasure"] != pt]
        
birthsAndFertility.to_csv("NPP_BirthsAndFertility.csv", index=False)

birthsAndFertility[:3] # sanity check
# Out:
#      V4_0         time time_codelist       geography geography_codelist  \
# 0   533.0  2016 - 2017          Year  United Kingdom          K02000001
# 1  1457.0  2016 - 2017          Year  United Kingdom          K02000001
# 2  3934.0  2016 - 2017          Year  United Kingdom          K02000001
#
#    sex_codelist  sex age_codelist age projectiontype_codelist  \
# 0           2.0  2.0           15  15     low-life-expectancy
# 1           2.0  2.0           16  16     low-life-expectancy
# 2           2.0  2.0           17  17     low-life-expectancy
#
#         projectiontype populationmeasure_codelist populationmeasure
# 0  Low life expectancy                     births            Births
# 1  Low life expectancy                     births            Births
# 2  Low life expectancy                     births            Births
